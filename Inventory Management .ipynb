# %% [markdown]
# # Inventory Management System

# %%
The project of inventory management system using JSON files.

# %%
import json

fd = open("record.json",'r')
r = fd.read()
fd.close()

records = json.loads(r)

# %%
records
# Out:
# {'101': {'name': 'Degtergents',
#   'category': 'Toiletories',
#   'price': '10',
#   'unit_left': '90'},
#  '102': {'name': 'Tooth Paste',
#   'category': 'Toiletories',
#   'price': '25',
#   'unit_left': '51'},
#  '103': {'name': 'Sun Flower Oil',
#   'category': 'Kitchen Items',
#   'price': '85',
#   'units_left': '10'},
#  '104': {'name': 'Broom',
#   'category': 'Home Care',
#   'price': '25',
#   'unit_left': '51'},
#  '105': {'name': 'Vacum Cleaner',
#   'category': 'Home Care',
#   'price': '4500',
#   'unit_left': '4'},
#  '106': {'name': 'Knife',
#   'category': 'Kitchen Items',
#   'price': '60',
#   'units_left': '83'},
#  '107': {'name': 'Body Soap',
#   'category': 'Toiletories',
#   'price': '40',
#   'unit_left': '45'},
#  '108': {'name': 'Wheet Powder',
#   'category': 'Kitchen Items',
#   'price': '80',
#   'units_left': '23'},
#  '109': {'name': 'Rice',
#   'category': 'Kitchen Items',
#   'price': '50',
#   'units_left': '14'},
#  '110': {'name': 'Kit Kat',
# ...

# %%
#Add new items to the list
#Which will be recorded in the dictionary

a = int(input("Enter item id: "))
b = input("Enter the name of the item: ")
c = input("Enter the category of the item: ")
d = int(input("Enter the price: "))
e = int(input("Units in stock: "))
record[a] = {"name":b,"category":c,"price":d,"units_left":e}

#Purchasing one item from the dictioanry
x=input("Enter product you wanna buy: ")
for i in record:
    if(record[i]["name"]==x):
        print("units_left :",end=' ')
        print(record[i]['units_left'])
        
#customer buys the items and sale is decieded
x=int(input("Count of items would you like to buy? "))
sum=0 
i=1
copy=0
copy1=0
while(i<=x):
    y=input("Enter the product you want to buy: ")
    for j in record:
        if(record[j]['name']==y):
            copy=j
            cost=record[j]['price']
    p=int(input("How many items of this product would you like? "))
    copy1=copy
    total_cost=cost*p;#displaying the total cost of the no. of items of that particular category bought by the customer
    print("Total cost :", total_cost)
    sum=sum+total_cost
    for j in record:
        if(record[j]['name']==y):
            record[j]['units_left']-=p #decreasing the available stock by no. of units sold
    for j in record_sales:
        if(record_sales[j]['name']==y):
            record_sales[j]['units_sold:']+=p  #increasing the no. of units sold      
             
    i=i+1      
print("Final bill = ", sum)

#Updating the stock in the inventory 
record["102"]["units_left"]=51

#Delete an item from the inventory 
pid = input("Please enter the product id of item you want to remove : ")

 choice = input("\nEnter y to confirm / n to discard : ") 

                if choice.lower() == 'y':
                    record[pid]
                    print("\nItem deleted successfully...\n")
                    break
                else:
                    print("\nDiscarded choice...\n")
                    break

            else:
                print("\nThe product id entered could not be found in the inventory!\n")

# %%
sales = {
        "101": {
                "name": "Degtergents",
                "units_sold": "0",
                "unit_left": "90"
        },
        "102": {
                "name": "Tooth Paste",
                "units_sold": "0",
                "unit_left": "51"
        },
        "103": {
                "name": "Sun Flower Oil",
                "units_sold": "1",
                "units_left": "9"
        },
        "104": {
                "name": "Broom",
                "units_sold": "",
                "unit_left": "51"
        },
        "105": {
                "name": "Vacum Cleaner",
                "units_sold": "0",
                "unit_left": "4"
        },
        "106": {
                "name": "Knife",
                "units_sold": "",
                "units_left": "83"
        },
        "107": {
                "name": "Body Soap",
                "units_sold": "0",
                "unit_left": "45"
        },
        "108": {
                "name": "Wheet Powder",
                "units_sold": "0",
                "units_left": "23"
        },
        "109": {
                "name": "Rice",
                "units_sold": "0",
                "units_left": "14"
        },
        "110": {
                "name": "Kit Kat",
                "units_sold": "5",
                "units_left": "65"
        },
        "111": {
                "name": "Ballpen",
                "units_sold": "3",
                "units_left": "43"
        },
        "112": {
                "name": "Dinning Table",
                "units_sold": "0",
                "units_left": "31"
        },
        "113": {
                "name": "Calculator",
                "units_sold": "1",
                "units_left": "18"
        },
        "114": {
                "name": "Brown Envelope",
                "units_sold": "0",
                "units_left": "64"
        },
        "115": {
                "name": "Desk",
                "units_sold": "0",
                "units_left": "20"
        },
        "116": {
                "name": "Lamp",
                "units_sold": "0",
                "units_left": "18"
        },
        "117": {
                "name": "Speakers",
                "units_sold": "0",
                "units_left": "34"
        },
        "118": {
                "name": "Printer",
                "units_sold": "0",
                "units_left": "28"
        },
        "119": {
                "name": "Books",
                "units_sold": "",
                "units_left": "112"
        },
        "120": {
                "name": "Bread",
                "units_sold": "2",
                "units_left": "45"
        },
        "121": {
                "name": "Butter",
                "units_sold": "1",
                "units_left": "31"
        },
        "122": {
                "name": "Spoon",
                "units_sold": "4",
                "units_left": "52"
        },
        "123": {
                "name": "Pan",
                "units_sold": "0",
                "units_left": "19"
        },
        "124": {
                "name": "Colours",
                "units_sold": "0",
                "units_left": "64"
        },
        "125": {
                "name": "Oven",
                "units_sold": "1",
                "units_left": "37"
        },
}
